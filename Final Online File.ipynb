# %%
import requests
import subprocess
import json

# Step 1: Call ChatGPT API
def call_chatgpt(prompt):
    api_key = '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'
    headers = {
        'Authorization': f'Bearer {api_key}',
        'Content-Type': 'application/json',
    }
    
    data = {
        'model': 'gpt-4',
        'messages': [{'role': 'user', 'content': prompt}],
        'max_tokens': 100,
    }
    
    response = requests.post('https://api.openai.com/v1/chat/completions', headers=headers, json=data)
    response_json = response.json()
    
    if response_json and 'choices' in response_json and len(response_json['choices']) > 0:
        return response_json['choices'][0]['message']['content']
    else:
        return "No response from ChatGPT."

# Step 2: Use curl to send data to Google Sheets
def send_to_google_sheets(prompt, response):
    url = 'https://script.google.com/macros/s/AKfycbyrjJ9Vc5l9WYR9hWBKbqLQj3Ima-7uDn1T8nvmTd1mc2SNAvw3yMvPllFzv3Hxkkcs/exec'
    
    # Data payload
    payload = json.dumps({
        'prompt': prompt,
        'response': response
    })
    
    # Construct the curl command
    curl_command = [
        'curl',
        '-X', 'POST', url,
        '-H', 'Content-Type: application/json',
        '-d', payload
    ]
    
    # Execute the curl command
    subprocess.run(curl_command, check=True)

# Step 3: Main Function (Modified to continue taking prompts)
def main():
    print("Enter 'exit' to quit the program.")
    
    while True:
        prompt = input("Enter your prompt for ChatGPT: ")
        
        # Exit the loop if the user types 'exit'
        if prompt.lower() == "exit":
            print("Exiting the program. Goodbye!")
            break
        
        # Get the response from ChatGPT
        chatgpt_response = call_chatgpt(prompt)
        print(f"ChatGPT Response: {chatgpt_response}")
        
        # Send the prompt and response to Google Sheets
        send_to_google_sheets(prompt, chatgpt_response)
        print("Data sent to Google Sheets successfully.\n")

if __name__ == "__main__":
    main()
